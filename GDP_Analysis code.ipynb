# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/world.csv',decimal=',')

# %%
data.shape
# Out:
# (149, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             149 non-null    object
#  1   Region                              149 non-null    object
#  2   Population                          149 non-null    int64
#  3   Area (sq. mi.)                      149 non-null    int64
#  4   Pop. Density (per sq. mi.)          149 non-null    float64
#  5   Coastline (coast/area ratio)        149 non-null    float64
#  6   Net migration                       149 non-null    float64
#  7   Infant mortality (per 1000 births)  149 non-null    float64
#  8   GDP ($ per capita)                  149 non-null    int64
#  9   Literacy (%)                        145 non-null    float64
#  10  Phones (per 1000)                   149 non-null    float64
#  11  Arable (%)                          149 non-null    float64
#  12  Crops (%)                           149 non-null    float64
#  13  Other (%)                           149 non-null    float64
#  14  Climate                             148 non-null    float64
#  15  Birthrate                           149 non-null    float64
#  16  Deathrate                           149 non-null    float64
#  17  Agriculture                         149 non-null    float64
#  18  Industry                            149 non-null    float64
#  19  Service                             149 non-null    float64
# dtypes: float64(15), int64(3), object(2)
# memory usage: 23.4+ KB

# %%
data.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                      int64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
data.head()
# Out:
#         Country                               Region  Population  \
# 0  Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1    Argentina               LATIN AMER. & CARIB        39921833
# 2    Australia   OCEANIA                                20264082
# 3      Austria   WESTERN EUROPE                          8192880
# 4   Bangladesh         ASIA (EX. NEAR EAST)            147365352
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1         2766890                        14.4                          0.18
# 2         7686850                         2.6                          0.34
# 3           83870                        97.7                          0.00
# 4          144000                      1023.4                          0.40
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07                 700
# 1           0.61                               15.18               11200
# 2           3.98                                4.69               29000
# 3           2.00                                4.66               30000
# 4          -0.71                               62.60                1900
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          97.1              220.4       12.31       0.48      87.21      3.0
# 2         100.0              565.5        6.55       0.04      93.41      1.0
# 3          98.0              452.2       16.91       0.86      82.23      3.0
# 4          43.1                7.3       62.11       3.07      34.82      2.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      16.73       7.55        0.095     0.358    0.547
# 2      12.14       7.51        0.038     0.262    0.700
# 3       8.74       9.76        0.018     0.304    0.678
# 4      29.80       8.27        0.199     0.198    0.603

# %%
data.tail()
# Out:
#              Country                               Region  Population  \
# 144  Virgin Islands               LATIN AMER. & CARIB          108605
# 145       West Bank   NEAR EAST                               2460492
# 146           Yemen   NEAR EAST                              21456188
# 147          Zambia   SUB-SAHARAN AFRICA                     11502010
# 148        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 144            1910                        56.9                          9.84
# 145            5860                       419.9                          0.00
# 146          527970                        40.6                          0.36
# 147          752614                        15.3                          0.00
# 148          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 144          -8.94                                8.03               17200
# 145           2.98                               19.62                 800
# 146           0.00                               61.50                 800
# 147           0.00                               88.29                 800
# 148           0.00                               67.69                1900
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 144           NaN              652.8       11.76       2.94      85.30
# 145           NaN              145.2       16.90      18.97      64.13
# 146          50.2               37.2        2.78       0.24      96.98
# 147          80.6                8.2        7.08       0.03      92.90
# 148          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 144      2.0      13.96       6.43        0.010     0.190    0.800
# 145      3.0      31.67       3.92        0.090     0.280    0.630
# 146      1.0      42.89       8.30        0.135     0.472    0.393
# 147      2.0      41.00      19.93        0.220     0.290    0.489
# 148      2.0      28.01      21.84        0.179     0.243    0.579

# %%
data.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          4
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               1
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
data.describe(include='all')
# Out:
#              Country                               Region    Population  \
# count            149                                  149  1.490000e+02
# unique           149                                   11           NaN
# top     Afghanistan   SUB-SAHARAN AFRICA                            NaN
# freq               1                                   35           NaN
# mean             NaN                                  NaN  4.191753e+07
# std              NaN                                  NaN  1.438551e+08
# min              NaN                                  NaN  2.057900e+04
# 25%              NaN                                  NaN  2.418393e+06
# 50%              NaN                                  NaN  8.989046e+06
# 75%              NaN                                  NaN  2.828715e+07
# max              NaN                                  NaN  1.313974e+09
#
#         Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count     1.490000e+02                  149.000000
# unique             NaN                         NaN
# top                NaN                         NaN
# freq               NaN                         NaN
# mean      8.123907e+05                  211.183893
# std       2.154358e+06                  746.488804
# min       1.160000e+02                    1.800000
# 25%       3.052800e+04                   26.900000
# 50%       1.810400e+05                   66.600000
# 75%       5.870400e+05                  173.400000
# max       1.707520e+07                 6482.200000
#
#         Coastline (coast/area ratio)  Net migration  \
# count                     149.000000     149.000000
# unique                           NaN            NaN
# top                              NaN            NaN
# freq                             NaN            NaN
# mean                       15.849060      -0.018121
# std                        78.834204       4.874972
# min                         0.000000     -20.990000
# 25%                         0.100000      -1.310000
# 50%                         0.470000       0.000000
# 75%                         4.350000       0.680000
# max                       870.660000      23.060000
#
#         Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# count                           149.000000          149.000000    145.000000
# unique                                 NaN                 NaN           NaN
# top                                    NaN                 NaN           NaN
# freq                                   NaN                 NaN           NaN
# mean                             38.634698         9441.610738     81.693793
# std                              36.543952        10088.072303     20.365443
# min                               2.290000          500.000000     17.600000
# 25%                               8.600000         1800.000000     69.400000
# 50%                              23.570000         5400.000000     90.900000
# 75%                              62.600000        13100.000000     98.000000
# max                             163.070000        37800.000000    100.000000
#
#         Phones (per 1000)  Arable (%)   Crops (%)   Other (%)     Climate  \
# count          149.000000  149.000000  149.000000  149.000000  148.000000
# unique                NaN         NaN         NaN         NaN         NaN
# top                   NaN         NaN         NaN         NaN         NaN
# freq                  NaN         NaN         NaN         NaN         NaN
# mean           215.564430   14.380336    4.167919   81.451141    2.101351
# std            217.566063   13.221237    7.355631   16.089246    0.716567
# min              0.200000    0.000000    0.000000   33.330000    1.000000
# 25%             26.800000    3.850000    0.240000   70.490000    2.000000
# 50%            142.400000   10.950000    1.030000   85.700000    2.000000
# 75%            336.300000   20.960000    4.170000   94.400000    3.000000
# max            898.000000   62.110000   45.710000  100.000000    4.000000
#
#          Birthrate   Deathrate  Agriculture    Industry     Service
# count   149.000000  149.000000   149.000000  149.000000  149.000000
# unique         NaN         NaN          NaN         NaN         NaN
# top            NaN         NaN          NaN         NaN         NaN
# freq           NaN         NaN          NaN         NaN         NaN
# mean     22.959732    9.406510     0.161919    0.287698    0.549738
# std      11.532136    4.644878     0.160491    0.139977    0.169902
# min       7.290000    2.410000     0.000000    0.020000    0.062000
# 25%      13.640000    5.980000     0.038000    0.200000    0.411000
# 50%      20.340000    8.250000     0.100000    0.275000    0.559000
# 75%      31.980000   11.550000     0.234000    0.348000    0.678000
# max      50.730000   23.100000     0.769000    0.906000    0.954000

# %%
data['Climate'].fillna(data['Climate'].mode()[0],inplace=True)

# %%
data['Climate'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          4
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %% [markdown]
# # Data Exploration
#  **Top Countries with highest GDP per capita**

# %%
fig, ax = plt.subplots(figsize=(16,6))
#ax = fig.add_subplot(111)
top_gdp_countries = data.sort_values('GDP ($ per capita)',ascending=False).head(20)
mean = pd.DataFrame({'Country':['World mean'], 'GDP ($ per capita)':[data['GDP ($ per capita)'].mean()]})
gdps = pd.concat([top_gdp_countries[['Country','GDP ($ per capita)']],mean],ignore_index=True)

sns.barplot(x='Country',y='GDP ($ per capita)',data=gdps, palette='Set3')
ax.set_xlabel(ax.get_xlabel(),labelpad=15)
ax.set_ylabel(ax.get_ylabel(),labelpad=30)
ax.xaxis.label.set_fontsize(16)
ax.yaxis.label.set_fontsize(16)
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
#ax = fig.add_subplot(111)
gdp = data.sort_values('GDP ($ per capita)',ascending=False).head(20)
pop = data.sort_values('Population',ascending=False).head(20)
mean = pd.DataFrame({'Population':[data['Population'].mean()], 'GDP ($ per capita)':[data['GDP ($ per capita)'].mean()]})
gdps = pd.concat([gdp[['Population','GDP ($ per capita)']],mean],ignore_index=True)

sns.barplot(x='Population',y='GDP ($ per capita)',data=gdps, palette='Set3')
ax.set_xlabel(ax.get_xlabel(),labelpad=15)
ax.set_ylabel(ax.get_ylabel(),labelpad=30)
ax.xaxis.label.set_fontsize(16)
ax.yaxis.label.set_fontsize(16)
plt.xticks(rotation=90)
plt.show()
